# %% [markdown]
# # Transformasi Data

# %% [markdown]
# ## 5 Maret 2019

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("pcademo.csv")
data.head()
# Out:
#         State  Census Resident Total Population - Apr-1-2000  \
# 0     Alabama                                      4447100.0
# 1      Alaska                                       626932.0
# 2     Arizona                                      5130632.0
# 3    Arkansas                                      2673400.0
# 4  California                                     33871648.0
#
#    Resident Total Population Estimate - Jul-1-2000  \
# 0                                        4451493.0
# 1                                         627601.0
# 2                                        5165274.0
# 3                                        2678030.0
# 4                                       34000446.0
#
#    Resident Total Population Estimate - Jul-1-2001  \
# 0                                        4464356.0
# 1                                         634892.0
# 2                                        5307331.0
# 3                                        2692090.0
# ...

# %%
#cara mengambil data tertentu saja/memotong data
x=data.iloc[0:51,1:20]
x.tail()
# Out:
#     Census Resident Total Population - Apr-1-2000  \
# 46                                      7078515.0
# 47                                      5894121.0
# 48                                      1808344.0
# 49                                      5363675.0
# 50                                       493782.0
#
#     Resident Total Population Estimate - Jul-1-2000  \
# 46                                        7104016.0
# 47                                        5908372.0
# 48                                        1807099.0
# 49                                        5372243.0
# 50                                         494001.0
#
#     Resident Total Population Estimate - Jul-1-2001  \
# 46                                        7187734.0
# 47                                        5987973.0
# 48                                        1801916.0
# 49                                        5401906.0
# 50                                         494423.0
#
# ...

# %%
#normalization
from sklearn.preprocessing import normalize
xnorm=normalize(x,norm='l2') #default norm l2, other are l1 and max
xnorm=pd.DataFrame(xnorm)
xnorm.tail()
# Out:
#           0         1         2         3         4         5             6   \
# 46  0.462700  0.464367  0.469840  0.000531  0.001196  0.000015 -7.922467e-05
# 47  0.462826  0.463946  0.470196  0.000033  0.001727  0.000007 -3.486439e-05
# 48  0.473139  0.472813  0.471457 -0.000369 -0.001162  0.000000 -2.616422e-07
# 49  0.467409  0.468156  0.470741  0.000134  0.000259  0.000000 -4.357173e-07
# 50  0.466655  0.466862  0.467261 -0.000377 -0.001929  0.000005 -2.551669e-05
#
#           7         8         9         10        11        12        13  \
# 46  0.000374  0.001479  0.001592  0.006549  0.000860  0.003748  0.412350
# 47  0.000412  0.001732  0.001522  0.006308  0.000814  0.003509  0.411790
# 48  0.000034  0.000128  0.001319  0.005347  0.001292  0.005608  0.400400
# 49  0.000137  0.000528  0.001455  0.005981  0.000964  0.004120  0.406886
# 50  0.000095  0.000369  0.001399  0.005793  0.000922  0.003761  0.412216
#
#           14        15        16        17        18
# ...

# %%
#minmax
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(-5,1))
scaler.fit(x)
x_scaled=scaler.transform(x)
x_scaled=pd.DataFrame(x_scaled)
x_scaled.tail()
# Out:
#           0         1         2         3         4         5         6   \
# 46 -3.816329 -3.816344 -3.819060 -0.837422 -1.735456 -0.857143 -3.799207
# 47 -4.029236 -4.030448 -4.030741 -1.443074 -1.681392 -3.517857 -0.755614
# 48 -4.763695 -4.764864 -4.769311 -1.587599 -2.068107 -5.000000  1.000000
# 49 -4.124589 -4.126453 -4.134144 -1.355619 -1.959627 -5.000000  0.984148
# 50 -5.000000 -5.000000 -5.000000 -1.507937 -2.032986 -4.910714  0.896962
#
#           7         8         9         10        11        12        13  \
# 46 -4.529964 -4.508216 -3.930357 -3.923450 -3.596840 -3.573392 -3.823774
# 47 -4.569434 -4.520748 -4.162506 -4.150634 -3.910890 -3.905361 -4.036916
# 48 -4.997575 -4.997281 -4.833465 -4.836259 -4.521223 -4.515109 -4.780831
# 49 -4.876993 -4.874286 -4.288401 -4.284639 -3.832968 -3.837294 -4.152097
# 50 -5.000000 -4.999514 -5.000000 -5.000000 -4.966605 -4.972957 -5.000000
#
#           14        15        16        17        18
# ...

# %%
#3igmoid
xsigmoidal=(1-2.718281818**(-xnorm))/(1+2.718281818**(-xnorm))
xsigmoidal=pd.DataFrame(xsigmoidal)
xsigmoidal.tail()
# Out:
#           0         1         2         3         4         5             6   \
# 46  0.227309  0.228099  0.230692  0.000265  0.000598  0.000008 -3.961233e-05
# 47  0.227369  0.227899  0.230860  0.000017  0.000864  0.000003 -1.743220e-05
# 48  0.232253  0.232099  0.231457 -0.000185 -0.000581  0.000000 -1.308211e-07
# 49  0.229541  0.229894  0.231118  0.000067  0.000130  0.000000 -2.178586e-07
# 50  0.229183  0.229282  0.229470 -0.000189 -0.000964  0.000002 -1.275835e-05
#
#           7         8         9         10        11        12        13  \
# 46  0.000187  0.000739  0.000796  0.003274  0.000430  0.001874  0.203302
# 47  0.000206  0.000866  0.000761  0.003154  0.000407  0.001754  0.203034
# 48  0.000017  0.000064  0.000659  0.002673  0.000646  0.002804  0.197567
# 49  0.000068  0.000264  0.000727  0.002990  0.000482  0.002060  0.200682
# 50  0.000047  0.000184  0.000699  0.002897  0.000461  0.001881  0.203238
#
#           14        15        16        17        18
# ...

# %%
#desimal scalling
xdecimal=x/(10**5)
xdecimal=pd.DataFrame(xdecimal)
xdecimal.tail()
# Out:
#     Census Resident Total Population - Apr-1-2000  \
# 46                                       70.78515
# 47                                       58.94121
# 48                                       18.08344
# 49                                       53.63675
# 50                                        4.93782
#
#     Resident Total Population Estimate - Jul-1-2000  \
# 46                                         71.04016
# 47                                         59.08372
# 48                                         18.07099
# 49                                         53.72243
# 50                                          4.94001
#
#     Resident Total Population Estimate - Jul-1-2001  \
# 46                                         71.87734
# 47                                         59.87973
# 48                                         18.01916
# 49                                         54.01906
# 50                                          4.94423
#
# ...

# %%
#softmax (fungsi dibuat sendiri)
def softmax(x):
    return np.exp(x)/np.sum(np.exp(x), axis=0)
xsoft=softmax(xnorm)
xsoft=pd.DataFrame(xsoft)
xsoft.tail()
# Out:
#           0         1         2         3         4         5         6   \
# 46  0.019544  0.019558  0.019593  0.019618  0.019629  0.019608  0.019607
# 47  0.019547  0.019550  0.019600  0.019608  0.019639  0.019608  0.019608
# 48  0.019749  0.019724  0.019625  0.019600  0.019582  0.019608  0.019608
# 49  0.019637  0.019633  0.019611  0.019610  0.019610  0.019608  0.019608
# 50  0.019622  0.019607  0.019543  0.019600  0.019567  0.019608  0.019608
#
#           7         8         9         10        11        12        13  \
# 46  0.019609  0.019613  0.019608  0.019608  0.019606  0.019601  0.019687
# 47  0.019610  0.019618  0.019607  0.019604  0.019605  0.019596  0.019676
# 48  0.019603  0.019587  0.019603  0.019585  0.019614  0.019637  0.019453
# 49  0.019605  0.019595  0.019605  0.019597  0.019608  0.019608  0.019579
# 50  0.019604  0.019592  0.019604  0.019594  0.019607  0.019601  0.019684
#
#           14        15        16        17        18
# ...

# %%
#feature selection (mencari skor)
from sklearn.feature_selection import SelectKBest, chi2, f_regression
Xx=x.iloc[0:51,1:20]
y=x.iloc[0:51,1]
selector=SelectKBest(f_regression,k="all").fit(Xx,y)
X_new= selector.transform(Xx)
scores= selector.scores_
scores
# Out:
# array([1.10338191e+17, 5.61375136e+05, 3.36516052e+00, 1.44451214e+00,
#        4.99675650e+01, 4.33492917e+01, 2.71500530e+02, 2.81466705e+02,
#        3.05153091e+03, 3.01376496e+03, 1.09412350e+03, 1.02966997e+03,
#        4.78297078e+04, 4.08507686e+04, 8.40708042e+02, 8.74017871e+02,
#        1.53597567e+00, 3.97449012e+00])
